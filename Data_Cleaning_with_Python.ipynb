# %%
# import pandas

import pandas as pd

# %%
# import the dataset

df = pd.read_excel(r'C:\Users\iphy2\Downloads\Python Files2\test_pythonLH23.xlsx')

# %%
#read the raw and dirty dataset

df
# Out:
#    IMBD title ID                Original titlÃŠ         Release year  \
# 0      tt0111161       The Shawshank Redemption  1995-02-10 00:00:00
# 1      tt0068646                  The Godfather           09 21 1972
# 2      tt0468569                The Dark Knight          23 -07-2008
# 3      tt0071562         The Godfather: Part II  1975-09-25 00:00:00
# 4      tt0110912                   Pulp Fiction  1994-10-28 00:00:00
# ..           ...                            ...                  ...
# 95     tt0070735                      The Sting  1974-03-21 00:00:00
# 96     tt0082096                       Das Boot  1982-03-18 00:00:00
# 97     tt0059578  Per qualche dollaro in piÃƒÂ¹  1965-12-20 00:00:00
# 98     tt1832382        Jodaeiye Nader az Simin  2011-10-21 00:00:00
# 99     tt0045152            Singin' in the Rain  1953-02-05 00:00:00
#
#                       GenrÃ«Â¨ Duration       Country Content Rating  \
# ...

# %%
# view all the columns
df.columns
# Out:
# Index(['Original_title', 'Release year', 'Content Rating', 'Director',
#        'Duration_in_Hours', 'Countries', 'Scores', 'Votes', 'Genre', 'Income'],
#       dtype='object')

# %%
#check the first 5 rows and columns of the dataset

df.head()
# Out:
#   IMBD title ID           Original titlÃŠ         Release year  \
# 0     tt0111161  The Shawshank Redemption  1995-02-10 00:00:00
# 1     tt0068646             The Godfather           09 21 1972
# 2     tt0468569           The Dark Knight          23 -07-2008
# 3     tt0071562    The Godfather: Part II  1975-09-25 00:00:00
# 4     tt0110912              Pulp Fiction  1994-10-28 00:00:00
#
#                GenrÃ«Â¨ Duration Country Content Rating              Director  \
# 0                 Drama      142     USA              R        Frank Darabont
# 1          Crime, Drama      175     USA              R  Francis Ford Coppola
# 2  Action, Crime, Drama      152      US          PG-13     Christopher Nolan
# 3          Crime, Drama      220     USA              R  Francis Ford Coppola
# 4          Crime, Drama              USA              R     Quentin Tarantino
#
#    Unnamed: 8         Income   Votes  Score
# 0         NaN     $ 28815245  2278845   9.3
# ...

# %%
#check the last 5 columns and rows of the dataset

df.tail()
# Out:
#    IMBD title ID                Original titlÃŠ         Release year  \
# 95     tt0070735                      The Sting  1974-03-21 00:00:00
# 96     tt0082096                       Das Boot  1982-03-18 00:00:00
# 97     tt0059578  Per qualche dollaro in piÃƒÂ¹  1965-12-20 00:00:00
# 98     tt1832382        Jodaeiye Nader az Simin  2011-10-21 00:00:00
# 99     tt0045152            Singin' in the Rain  1953-02-05 00:00:00
#
#                       GenrÃ«Â¨ Duration       Country Content Rating  \
# 95        Comedy, Crime, Drama      129           USA             PG
# 96  Adventure, Drama, Thriller      149  West Germany              R
# 97                     Western      132         Italy            NaN
# 98                       Drama      123          Iran          PG-13
# 99    Comedy, Musical, Romance      103           USA            NaN
#
#              Director  Unnamed: 8       Income   Votes  Score
# 95    George Roy Hill         NaN  $ 156000000   236285   7.5
# ...

# %%
#check the info() of the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   IMBD title ID    100 non-null    object
#  1   Original titlÃŠ  100 non-null    object
#  2   Release year     100 non-null    object
#  3   GenrÃ«Â¨         100 non-null    object
#  4   Duration         99 non-null     object
#  5   Country          100 non-null    object
#  6   Content Rating   77 non-null     object
#  7   Director         100 non-null    object
#  8   Unnamed: 8       0 non-null      float64
#  9   Income           100 non-null    object
#  10   Votes           100 non-null    int64
#  11  Score            100 non-null    object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 9.5+ KB

# %%
#Check for null values

df.isnull()
# Out:
#     IMBD title ID  Original titlÃŠ  Release year  GenrÃ«Â¨  Duration  Country  \
# 0           False            False         False     False     False    False
# 1           False            False         False     False     False    False
# 2           False            False         False     False     False    False
# 3           False            False         False     False     False    False
# 4           False            False         False     False     False    False
# ..            ...              ...           ...       ...       ...      ...
# 95          False            False         False     False     False    False
# 96          False            False         False     False     False    False
# 97          False            False         False     False     False    False
# 98          False            False         False     False     False    False
# 99          False            False         False     False     False    False
#
# ...

# %%
#check all the numerical info of the dataset

df.describe()
# Out:
#        Unnamed: 8        Votes
# count         0.0  1.000000e+02
# mean          NaN  8.297713e+05
# std           NaN  4.829340e+05
# min           NaN  1.957890e+05
# 25%           NaN  3.890690e+05
# 50%           NaN  7.515385e+05
# 75%           NaN  1.102243e+06
# max           NaN  2.278845e+06

# %%
#drop the unwanted columns - IMBD title ID & Unnamed: 8

df.drop(['IMBD title ID', 'Unnamed: 8'], axis =1, inplace = True)

# %%
df
# Out:
#                   Original titlÃŠ         Release year  \
# 0        The Shawshank Redemption  1995-02-10 00:00:00
# 1                   The Godfather           09 21 1972
# 2                 The Dark Knight          23 -07-2008
# 3          The Godfather: Part II  1975-09-25 00:00:00
# 4                    Pulp Fiction  1994-10-28 00:00:00
# ..                            ...                  ...
# 95                      The Sting  1974-03-21 00:00:00
# 96                       Das Boot  1982-03-18 00:00:00
# 97  Per qualche dollaro in piÃƒÂ¹  1965-12-20 00:00:00
# 98        Jodaeiye Nader az Simin  2011-10-21 00:00:00
# 99            Singin' in the Rain  1953-02-05 00:00:00
#
#                       GenrÃ«Â¨ Duration       Country Content Rating  \
# 0                        Drama      142           USA              R
# 1                 Crime, Drama      175           USA              R
# 2         Action, Crime, Drama      152            US          PG-13
# ...

# %%
#Rename the columns spelt wrongly - 

df = df.rename(columns={"Original titlÃŠ": "Original_title"})
df = df.rename(columns={"GenrÃ«Â¨": "Genre"})

# %%
import numpy as np

# %%
# Trying to change the duration to hours
# replace empty strings with NaN

df['duration_hours'] = df['Duration'].replace('', np.nan)

# %%
# convert the 'Duration' column to numeric type

df['Duration'] = pd.to_numeric(df['Duration'], errors='coerce')

# %%
# find the rows where the conversion failed

invalid_rows = df['Duration'].isnull()

# %%
print(df[invalid_rows])
# Out:
#                                        Original_title         Release year  \
# 4                                        Pulp Fiction  1994-10-28 00:00:00
# 6                                    Schindler's List  1994-03-11 00:00:00
# 11  The Lord of the Rings: The Fellowship of the Ring  2002-01-18 00:00:00
# 13                                         The Matrix  1999-05-07 00:00:00
# 15     Star Wars: Episode V - The Empire Strikes Back  1980-09-19 00:00:00
# 17                    One Flew Over the Cuckoo's Nest  1976-11-18 00:00:00
#
#                          Genre  Duration      Country Content Rating  \
# 4                 Crime, Drama       NaN          USA              R
# 6    Biography, Drama, History       NaN          USA              R
# 11    Action, Adventure, Drama       NaN  New Zesland          PG-13
# 13              Action, Sci-Fi       NaN          USA              R
# 15  Action, Adventure, Fantasy       NaN          USA             PG
# ...

# %%
# remove the invalid rows

df = df.dropna()

# %%
#replace NaN values with a default value of 0

df['Duration'] = df['Duration'].fillna(0)

# %%
# replace infinity values with a very large integer value

df['Duration'] = df['Duration'].replace([np.inf, -np.inf], 10**9)

# %%
# convert the cleaned 'Duration' column to an integer column called 'duration_hours'

df['duration_hours'] = df['Duration'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 0 to 98
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Original_title  71 non-null     object
#  1   Release year    71 non-null     object
#  2   Genre           71 non-null     object
#  3   Duration        71 non-null     float64
#  4   Country         71 non-null     object
#  5   Content Rating  71 non-null     object
#  6   Director        71 non-null     object
#  7   Income          71 non-null     object
#  8    Votes          71 non-null     int64
#  9   Score           71 non-null     object
#  10  duration_hours  71 non-null     int32
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 6.4+ KB

# %%
# convert duration from minutes to hours

df['duration_hours'] = df['Duration'] / 60

# %%
df.head()
# Out:
#                                   Original_title         Release year  \
# 0                       The Shawshank Redemption  1995-02-10 00:00:00
# 1                                  The Godfather           09 21 1972
# 2                                The Dark Knight          23 -07-2008
# 3                         The Godfather: Part II  1975-09-25 00:00:00
# 5  The Lord of the Rings: The Return of the King  2004-02-22 00:00:00
#
#                       Genre  Duration      Country Content Rating  \
# 0                     Drama     142.0          USA              R
# 1              Crime, Drama     175.0          USA              R
# 2      Action, Crime, Drama     152.0           US          PG-13
# 3              Crime, Drama     220.0          USA              R
# 5  Action, Adventure, Drama     201.0  New Zealand          PG-13
#
#                Director         Income   Votes  Score  duration_hours
# 0        Frank Darabont     $ 28815245  2278845   9.3        2.366667
# ...

# %%
#drop the old Duration column

df.drop(['Duration'], axis =1, inplace = True)

# %%
# Rename new column duration-hour to 'Duration'

df.rename(columns={'duration_hours': 'Duration'})
# Out:
#                                    Original_title         Release year  \
# 0                        The Shawshank Redemption  1995-02-10 00:00:00
# 1                                   The Godfather           09 21 1972
# 2                                 The Dark Knight          23 -07-2008
# 3                          The Godfather: Part II  1975-09-25 00:00:00
# 5   The Lord of the Rings: The Return of the King  2004-02-22 00:00:00
# ..                                            ...                  ...
# 93                                         Jagten  2012-11-22 00:00:00
# 94                             Lawrence of Arabia  1963-10-29 00:00:00
# 95                                      The Sting  1974-03-21 00:00:00
# 96                                       Das Boot  1982-03-18 00:00:00
# 98                        Jodaeiye Nader az Simin  2011-10-21 00:00:00
#
#                           Genre       Country Content Rating  \
# ...

# %%
# check for the names of all the countries in the country column

df['Country'].unique()
# Out:
# array(['USA', 'US', 'New Zealand', 'UK', 'Italy', 'New Zeland', 'US.',
#        'Brazil', 'Japan', 'South Korea', 'Germany', 'France', 'Denmark',
#        'West Germany', 'Iran'], dtype=object)

# %%
corrections = {
    'US': 'USA',
    'US.': 'USA',
    'West Germany': 'Germany'
}

# %%
#Replace all corrections in country column

df['country'] = df['Country'].replace(corrections)

# %%
countries = df['country'].unique()

# %%
df
# Out:
#                                    Original_title         Release year  \
# 0                        The Shawshank Redemption  1995-02-10 00:00:00
# 1                                   The Godfather           09 21 1972
# 2                                 The Dark Knight          23 -07-2008
# 3                          The Godfather: Part II  1975-09-25 00:00:00
# 5   The Lord of the Rings: The Return of the King  2004-02-22 00:00:00
# ..                                            ...                  ...
# 93                                         Jagten  2012-11-22 00:00:00
# 94                             Lawrence of Arabia  1963-10-29 00:00:00
# 95                                      The Sting  1974-03-21 00:00:00
# 96                                       Das Boot  1982-03-18 00:00:00
# 98                        Jodaeiye Nader az Simin  2011-10-21 00:00:00
#
#                           Genre       Country Content Rating  \
# ...

# %%
#drop the old Country column

df.drop(['Country'], axis =1, inplace = True)

# %%
df
# Out:
#                                    Original_title         Release year  \
# 0                        The Shawshank Redemption  1995-02-10 00:00:00
# 1                                   The Godfather           09 21 1972
# 2                                 The Dark Knight          23 -07-2008
# 3                          The Godfather: Part II  1975-09-25 00:00:00
# 5   The Lord of the Rings: The Return of the King  2004-02-22 00:00:00
# ..                                            ...                  ...
# 93                                         Jagten  2012-11-22 00:00:00
# 94                             Lawrence of Arabia  1963-10-29 00:00:00
# 95                                      The Sting  1974-03-21 00:00:00
# 96                                       Das Boot  1982-03-18 00:00:00
# 98                        Jodaeiye Nader az Simin  2011-10-21 00:00:00
#
#                           Genre Content Rating              Director  \
# ...

# %%
# Remove the dollar sign from the column 'Income'

df['income'] = df['Income'].str.replace('$', '')
# Out:
# C:\Users\iphy2\AppData\Local\Temp\ipykernel_32448\3263541681.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['income'] = df['Income'].str.replace('$', '')

# %%
# Convert the income column to an integer type

df['income'] = df['income'].str.replace(',', '').str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 0 to 98
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Original_title  71 non-null     object
#  1   Release year    71 non-null     object
#  2   Genre           71 non-null     object
#  3   Content Rating  71 non-null     object
#  4   Director        71 non-null     object
#  5   Income          71 non-null     object
#  6    Votes          71 non-null     int64
#  7   Score           71 non-null     object
#  8   duration_hours  71 non-null     float64
#  9   country         71 non-null     object
#  10  income          71 non-null     object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 6.7+ KB

# %%
df
# Out:
#                                    Original_title         Release year  \
# 0                        The Shawshank Redemption  1995-02-10 00:00:00
# 1                                   The Godfather           09 21 1972
# 2                                 The Dark Knight          23 -07-2008
# 3                          The Godfather: Part II  1975-09-25 00:00:00
# 5   The Lord of the Rings: The Return of the King  2004-02-22 00:00:00
# ..                                            ...                  ...
# 93                                         Jagten  2012-11-22 00:00:00
# 94                             Lawrence of Arabia  1963-10-29 00:00:00
# 95                                      The Sting  1974-03-21 00:00:00
# 96                                       Das Boot  1982-03-18 00:00:00
# 98                        Jodaeiye Nader az Simin  2011-10-21 00:00:00
#
#                           Genre Content Rating              Director  \
# ...

# %%
#drop the old Income column

df.drop(['Income'], axis =1, inplace = True)

# %%
df
# Out:
#                                    Original_title         Release year  \
# 0                        The Shawshank Redemption  1995-02-10 00:00:00
# 1                                   The Godfather           09 21 1972
# 2                                 The Dark Knight          23 -07-2008
# 3                          The Godfather: Part II  1975-09-25 00:00:00
# 5   The Lord of the Rings: The Return of the King  2004-02-22 00:00:00
# ..                                            ...                  ...
# 93                                         Jagten  2012-11-22 00:00:00
# 94                             Lawrence of Arabia  1963-10-29 00:00:00
# 95                                      The Sting  1974-03-21 00:00:00
# 96                                       Das Boot  1982-03-18 00:00:00
# 98                        Jodaeiye Nader az Simin  2011-10-21 00:00:00
#
#                           Genre Content Rating              Director   Votes   \
# ...

# %%
# Remove non-numeric characters from the income column

df['income'] = df['income'].str.replace('[^0-9]', '', regex=True)

# %%
# Convert the income column to an integer type

df['income'] = df['income'].astype(int)

# %%
df.dtypes
# Out:
# Original_title     object
# Release year       object
# Genre              object
# Content Rating     object
# Director           object
#  Votes              int64
# Score              object
# duration_hours    float64
# country            object
# income              int32
# dtype: object

# %%
df
# Out:
#                                    Original_title         Release year  \
# 0                        The Shawshank Redemption  1995-02-10 00:00:00
# 1                                   The Godfather           09 21 1972
# 2                                 The Dark Knight          23 -07-2008
# 3                          The Godfather: Part II  1975-09-25 00:00:00
# 5   The Lord of the Rings: The Return of the King  2004-02-22 00:00:00
# ..                                            ...                  ...
# 93                                         Jagten  2012-11-22 00:00:00
# 94                             Lawrence of Arabia  1963-10-29 00:00:00
# 95                                      The Sting  1974-03-21 00:00:00
# 96                                       Das Boot  1982-03-18 00:00:00
# 98                        Jodaeiye Nader az Simin  2011-10-21 00:00:00
#
#                           Genre Content Rating              Director   Votes   \
# ...

# %%
#extract the year from the 'Release year' column

df['Release year'].str.extract('(\d{4})')
# Out:
#        0
# 0    NaN
# 1   1972
# 2   2008
# 3    NaN
# 5    NaN
# ..   ...
# 93   NaN
# 94   NaN
# 95   NaN
# 96   NaN
# 98   NaN
#
# [71 rows x 1 columns]

# %%
# extract the year from the 'Release year' column

df['Release year'] = df['Release year'].str.extract('(\d{4})')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Original_title  71 non-null     object
#  1   Release year    5 non-null      object
#  2   Genre           71 non-null     object
#  3   Content Rating  71 non-null     object
#  4   Director        71 non-null     object
#  5    Votes          71 non-null     int64
#  6   Score           71 non-null     object
#  7   duration_hours  71 non-null     float64
#  8   country         71 non-null     object
#  9   income          71 non-null     int32
# dtypes: float64(1), int32(1), int64(1), object(7)
# memory usage: 5.8+ KB

# %%
#Replace the empty rows in the release year column with 0

df['Release year'] = df['Release year'].str.extract('(\d{4})').fillna(0)

# %%
df
# Out:
#                                    Original_title Release year  \
# 0                        The Shawshank Redemption            0
# 1                                   The Godfather         1972
# 2                                 The Dark Knight         2008
# 3                          The Godfather: Part II            0
# 5   The Lord of the Rings: The Return of the King            0
# ..                                            ...          ...
# 93                                         Jagten            0
# 94                             Lawrence of Arabia            0
# 95                                      The Sting            0
# 96                                       Das Boot            0
# 98                        Jodaeiye Nader az Simin            0
#
#                           Genre Content Rating              Director   Votes   \
# 0                         Drama              R        Frank Darabont  2278845
# ...

# %%
# Remove non-numeric characters from the Score column

df['score'] = df['Score'].str.replace('[^0-9]', '', regex=True)

# %%
# convert the "score" column to a float data type and replace any missing values with NaN

df['score'] = df['score'].fillna(np.nan).astype(float)

# %%
df
# Out:
#                                    Original_title Release year  \
# 0                        The Shawshank Redemption            0
# 1                                   The Godfather         1972
# 2                                 The Dark Knight         2008
# 3                          The Godfather: Part II            0
# 5   The Lord of the Rings: The Return of the King            0
# ..                                            ...          ...
# 93                                         Jagten            0
# 94                             Lawrence of Arabia            0
# 95                                      The Sting            0
# 96                                       Das Boot            0
# 98                        Jodaeiye Nader az Simin            0
#
#                           Genre Content Rating              Director   Votes   \
# 0                         Drama              R        Frank Darabont  2278845
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 0 to 98
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Original_title  71 non-null     object
#  1   Release year    71 non-null     object
#  2   Genre           71 non-null     object
#  3   Content Rating  71 non-null     object
#  4   Director        71 non-null     object
#  5    Votes          71 non-null     int64
#  6   Score           71 non-null     object
#  7   duration_hours  71 non-null     float64
#  8   country         71 non-null     object
#  9   income          71 non-null     int32
#  10  score           69 non-null     float64
# dtypes: float64(2), int32(1), int64(1), object(7)
# memory usage: 6.4+ KB

# %%
# Correct the space before and after the column 'Votes'

df = df.rename(columns={" Votes ": "Votes1"})

# %%
df
# Out:
#                                    Original_title Release year  \
# 0                        The Shawshank Redemption            0
# 1                                   The Godfather         1972
# 2                                 The Dark Knight         2008
# 3                          The Godfather: Part II            0
# 5   The Lord of the Rings: The Return of the King            0
# ..                                            ...          ...
# 93                                         Jagten            0
# 94                             Lawrence of Arabia            0
# 95                                      The Sting            0
# 96                                       Das Boot            0
# 98                        Jodaeiye Nader az Simin            0
#
#                           Genre Content Rating              Director   Votes1  \
# 0                         Drama              R        Frank Darabont  2278845
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 0 to 98
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Original_title  71 non-null     object
#  1   Release year    71 non-null     object
#  2   Genre           71 non-null     object
#  3   Content Rating  71 non-null     object
#  4   Director        71 non-null     object
#  5   Votes1          71 non-null     int64
#  6   Score           71 non-null     object
#  7   duration_hours  71 non-null     float64
#  8   country         71 non-null     object
#  9   income          71 non-null     int32
#  10  score           69 non-null     float64
# dtypes: float64(2), int32(1), int64(1), object(7)
# memory usage: 6.4+ KB

# %%
# convert "vote" column to string and insert commas

df['votes'] = df['Votes1'].apply(lambda x: "{:,}".format(x))

# %%
df
# Out:
#                                    Original_title Release year  \
# 0                        The Shawshank Redemption            0
# 1                                   The Godfather         1972
# 2                                 The Dark Knight         2008
# 3                          The Godfather: Part II            0
# 5   The Lord of the Rings: The Return of the King            0
# ..                                            ...          ...
# 93                                         Jagten            0
# 94                             Lawrence of Arabia            0
# 95                                      The Sting            0
# 96                                       Das Boot            0
# 98                        Jodaeiye Nader az Simin            0
#
#                           Genre Content Rating              Director   Votes1  \
# 0                         Drama              R        Frank Darabont  2278845
# ...

# %%
#drop the old Votes1 column

df.drop(['Votes1'], axis =1, inplace = True)

# %%
# split the 'genre' column on the delimiter ',' and select the first element

df['genre'] = df['Genre'].str.split(',').str[0]

# %%
df
# Out:
#                                    Original_title Release year  \
# 0                        The Shawshank Redemption            0
# 1                                   The Godfather         1972
# 2                                 The Dark Knight         2008
# 3                          The Godfather: Part II            0
# 5   The Lord of the Rings: The Return of the King            0
# ..                                            ...          ...
# 93                                         Jagten            0
# 94                             Lawrence of Arabia            0
# 95                                      The Sting            0
# 96                                       Das Boot            0
# 98                        Jodaeiye Nader az Simin            0
#
#                           Genre Content Rating              Director Score  \
# 0                         Drama              R        Frank Darabont   9.3
# ...

# %%
# convert "income" column to string and insert commas

df['Income'] = df['income'].apply(lambda x: "{:,}".format(x))

# %%
df
# Out:
#                                    Original_title Release year  \
# 0                        The Shawshank Redemption            0
# 1                                   The Godfather         1972
# 2                                 The Dark Knight         2008
# 3                          The Godfather: Part II            0
# 5   The Lord of the Rings: The Return of the King            0
# ..                                            ...          ...
# 93                                         Jagten            0
# 94                             Lawrence of Arabia            0
# 95                                      The Sting            0
# 96                                       Das Boot            0
# 98                        Jodaeiye Nader az Simin            0
#
#                           Genre Content Rating              Director Score  \
# 0                         Drama              R        Frank Darabont   9.3
# ...

# %%
#drop the old Genre column

df.drop(['Genre'], axis =1, inplace = True)

# %%
#drop the old income column

df.drop(['income'], axis =1, inplace = True)

# %%
df
# Out:
#                                    Original_title Release year Content Rating  \
# 0                        The Shawshank Redemption            0              R
# 1                                   The Godfather         1972              R
# 2                                 The Dark Knight         2008          PG-13
# 3                          The Godfather: Part II            0              R
# 5   The Lord of the Rings: The Return of the King            0          PG-13
# ..                                            ...          ...            ...
# 93                                         Jagten            0              R
# 94                             Lawrence of Arabia            0             PG
# 95                                      The Sting            0             PG
# 96                                       Das Boot            0              R
# 98                        Jodaeiye Nader az Simin            0          PG-13
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 0 to 98
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Original_title  71 non-null     object
#  1   Release year    71 non-null     object
#  2   Content Rating  71 non-null     object
#  3   Director        71 non-null     object
#  4   Score           71 non-null     object
#  5   duration_hours  71 non-null     float64
#  6   country         71 non-null     object
#  7   score           69 non-null     float64
#  8   votes           71 non-null     object
#  9   genre           71 non-null     object
#  10  Income          71 non-null     object
# dtypes: float64(2), object(9)
# memory usage: 6.7+ KB

# %%
#drop the old Score column

df.drop(['Score'], axis =1, inplace = True)

# %%
df
# Out:
#                                    Original_title Release year Content Rating  \
# 0                        The Shawshank Redemption            0              R
# 1                                   The Godfather         1972              R
# 2                                 The Dark Knight         2008          PG-13
# 3                          The Godfather: Part II            0              R
# 5   The Lord of the Rings: The Return of the King            0          PG-13
# ..                                            ...          ...            ...
# 93                                         Jagten            0              R
# 94                             Lawrence of Arabia            0             PG
# 95                                      The Sting            0             PG
# 96                                       Das Boot            0              R
# 98                        Jodaeiye Nader az Simin            0          PG-13
#
# ...

# %%
# Remove non-numeric characters from the Vote column

df['votes'] = df['votes'].str.replace('[^0-9]', '', regex=True)

# %%
# convert the "score" column to a float data type and replace any missing values with NaN

df['votes'] = df['votes'].fillna(np.nan).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Original_title  71 non-null     object
#  1   Release year    71 non-null     object
#  2   Content Rating  71 non-null     object
#  3   Director        71 non-null     object
#  4   duration_hours  71 non-null     float64
#  5   country         71 non-null     object
#  6   score           69 non-null     float64
#  7   votes           71 non-null     float64
#  8   genre           71 non-null     object
#  9   Income          71 non-null     object
# dtypes: float64(3), object(7)
# memory usage: 6.1+ KB

# %%
# Replace any missing values with NaN
df['Release year'] = df['Release year'].replace('', np.nan)

# %%
# Convert the release year column to datetime

df['Release year'] = pd.to_datetime(df['Release year'], format='%Y', errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 0 to 98
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Original_title  71 non-null     object
#  1   Release year    5 non-null      datetime64[ns]
#  2   Content Rating  71 non-null     object
#  3   Director        71 non-null     object
#  4   duration_hours  71 non-null     float64
#  5   country         71 non-null     object
#  6   score           69 non-null     float64
#  7   votes           71 non-null     float64
#  8   genre           71 non-null     object
#  9   Income          71 non-null     object
# dtypes: datetime64[ns](1), float64(3), object(6)
# memory usage: 6.1+ KB

# %%
# Replace all the column names with the new clean column names to signify the clean data

df = df.rename(columns={"duration_hours": "Duration_in_Hours"})
df = df.rename(columns={"country": "Countries"})
df = df.rename(columns={"score": "Scores"})
df = df.rename(columns={"votes": "Votes"})
df = df.rename(columns={"genre": "Genre"})

# %%
df.head(10)
# Out:
#                                    Original_title Release year Content Rating  \
# 0                        The Shawshank Redemption          NaT              R
# 1                                   The Godfather   1972-01-01              R
# 2                                 The Dark Knight   2008-01-01          PG-13
# 3                          The Godfather: Part II          NaT              R
# 5   The Lord of the Rings: The Return of the King          NaT          PG-13
# 7                                    12 Angry Men          NaT      Not Rated
# 8                                       Inception          NaT          PG-13
# 9                                      Fight Club          NaT              R
# 10                                   Forrest Gump          NaT          PG-13
# 12                Il buono, il brutto, il cattivo   1966-01-01       Approved
#
#                 Director  Duration_in_Hours    Countries  Scores      Votes  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# count the number of movies by original title and country
country_counts = df.groupby(['Countries', 'Original_title']).size().reset_index(name='Count')

# create a horizontal bar chart of the title counts by country
plt.barh(country_counts['Countries'], country_counts['Count'])

# set the chart title and axis labels
plt.title('Number of Original Titles by Country')
plt.xlabel('Number of Movies')
plt.ylabel('Country')

# display the chart
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# filter the DataFrame to only include rows where the country is 'USA'
usa_movies = df[df['Countries'] == 'USA']

# count the number of movies by original title in the filtered DataFrame
title_counts = usa_movies['Original_title'].value_counts()

# create a bar chart of the title counts
plt.bar(title_counts.index, title_counts.values)

# set the chart title and axis labels
plt.title('Number of Original Titles Released in the USA')
plt.xlabel('Original Title')
plt.ylabel('Number of Movies')

# rotate the x-axis labels for better readability
plt.xticks(rotation=90)

# display the chart
plt.show()

# %%
# export the clean dataset to a csv file on the computer - #name the file 

df.to_csv('sample.csv', index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_32448\2662382434.py in <module>
#       1 # export the clean dataset to a csv file on the computer - #name the file
#       2
# ----> 3 df.to_csv('sample.csv', index)
#
# NameError: name 'index' is not defined

# %%
# used to display all the dataset, not just the first 5

pd.set_option('display max_row', None)
df.duration

# %%
#to replace a value in a column

df.duration.replace(' ', '0')

# %%
# to visualise

sns.countplot(data)
